# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(16,16))

font = {'family': 'serif',
        'font': 'Arial',
        'color':  'black',
        'weight': 'normal',
        'size': 400,
        }
ax.text(.35,.4,'t我', fontdict=font)
# Out:
# Text(0.35, 0.4, 't我')
# C:\Users\Lemon\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 25105 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Lemon\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 25105 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as mfm

#ya hei font, "exactly" the same as Arial Unicode
prop = mfm.FontProperties(fname='../Fonts/msyh.ttc')

fig, ax = plt.subplots(figsize=(16,16))
ax.text(.08,.2, s='\u4f4d', fontproperties=prop, fontsize=750)

matr = ax
np.shape(matr)
# Out:
# ()

# %%
import FormalImage as fi
import numpy as np
import matplotlib.pyplot as plt

charImg = fi.renderChar('\u4E4B', show=True)
print(np.shape(charImg))
# Out:
# (741, 800)

# %%
#all the strokes so far
strokeC0 = [[[0,0], [0.64989518, 0.33707865], [1, 1]]]
strokeC1 = [[[0, 0], [1.09574468, 0.12790698], [1.01595745, 0.50581395],[1, 1]]]
strokeC4 = [[ [0,1],[ 0.02970297, 0.08925319],[-0.03920792,0.03096539],[-0.01980198,-0.01371585],
       [0.0990099,-0.01025137],[1,0] ]]
strokeD0 = [[[0,.5], [1, .5]]]
strokeD1 = [[[.5,1], [.5, 0]]]

allStrokes = [strokeC0, strokeC1, strokeC4, strokeD0, strokeD1]
allStrokeNames = ['C0', 'C1', 'C4', 'D0', 'D1']

# %%
strokeDict = {}
strokeDict['c0'] = [[[0,0], [0.64989518, 0.33707865], [1, 1]]]
strokeDict['c1'] = [[[0, 0], [1.09574468, 0.12790698], [1.01595745, 0.50581395],[1, 1]]]
strokeDict['c4'] = [[ [0,1],[ 0.02970297, 0.08925319],[-0.03920792,0.03096539],[-0.01980198,-0.01371585],
       [0.0990099,-0.01025137],[1,0] ]]
strokeDict['d0'] = [[[0,.5], [1, .5]]]
strokeDict['d1'] = [[[.5,1], [.5, 0]]]

print(strokeDict['d0'])

strokeDict.save("test.json")
# Out:
# [[[0, 0.5], [1, 0.5]]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-c694d46b7ea0> in <module>
#       9 print(strokeDict['d0'])
#      10
# ---> 11 strokeDict.save("test.json")
#
# AttributeError: 'dict' object has no attribute 'save'

# %%
import numpy as np

np.save('HandStrokes.npy', strokeDict) 
np.save('FormalStrokes.npy', strokeDict)

# %%
d = np.load('HandStrokes.npy', allow_pickle=True).item()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-885b0f1ea1a3> in <module>
#       1 d = np.load('HandStrokes.npy', allow_pickle=True).item()
# ----> 2 d['e1']
#
# KeyError: 'e1'
