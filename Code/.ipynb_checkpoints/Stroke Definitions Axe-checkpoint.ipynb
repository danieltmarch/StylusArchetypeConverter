# %% [markdown]
# ## Stroke Definitions
# For each stroke type we need the hanzi and arial definition
# Each is saved using pickle (python library, not the fruit ☻)

# %%
import numpy as np
import matplotlib.pyplot as plt
from StrokeDef import StrokeType #needed for loading object properly
from StrokeDef import *


def plotStroke(stroke):
    fig, ax = plt.subplots(figsize=(8,8))
    ax.invert_yaxis()
    
    evalPoints = np.linspace(0.0, 1.0, 100) #start, end, resol, parametric t values
    for st in stroke: #control points, 
        #graph actual curve (bezier, use package)
        nodes = np.array(st).transpose()
        curve = bezier.Curve(nodes, degree=len(st)-1)
        curvePoints = np.array( curve.evaluate_multi(evalPoints).transpose().tolist()) #[[x,y]...]
        ax.plot(curvePoints[:,0], curvePoints[:,1], color="black")
        
    return fig, ax, curvePoints

# %% [markdown]
# ## Some simple strokes made
# Just a demonstration, also I've just done the arial definition for each type, so I'm using the arial def for the hanzi def as well.

# %%
strokeData = [[[0,1], [0.64989518, 1-0.33707865], [1, 0]]]
fig, ax, curvePoints = plotStroke(strokeData)

#make instance of strokeType class and set data
#strokeObj = StrokeType()
#strokeObj.set("C0", "㇀", strokeData, strokeData)
#save to data directory
#saveStroke(strokeObj)

#now show loading
strokeObj2 = loadStroke("HZZP")
fig, ax, curvePoints = plotStroke(strokeObj2.arial)
print(curvePoints)
# Out:
# [[1.         0.4       ]
#  [0.99793899 0.40606061]
#  [0.99579635 0.41212121]
#  [0.99357208 0.41818182]
#  [0.9912662  0.42424242]
#  [0.98887869 0.43030303]
#  [0.98640955 0.43636364]
#  [0.98385879 0.44242424]
#  [0.98122641 0.44848485]
#  [0.9785124  0.45454545]
#  [0.97571676 0.46060606]
#  [0.97283951 0.46666667]
#  [0.96988062 0.47272727]
#  [0.96684012 0.47878788]
#  [0.96371799 0.48484848]
#  [0.96051423 0.49090909]
#  [0.95722885 0.4969697 ]
#  [0.95386185 0.5030303 ]
#  [0.95041322 0.50909091]
#  [0.94688297 0.51515152]
#  [0.94327109 0.52121212]
#  [0.93957759 0.52727273]
#  [0.93580247 0.53333333]
#  [0.93194572 0.53939394]
#  [0.92800735 0.54545455]
#  [0.92398735 0.55151515]
#  [0.91988573 0.55757576]
#  [0.91570248 0.56363636]
#  [0.91143761 0.56969697]
#  [0.90709111 0.57575758]
#  [0.90266299 0.58181818]
#  [0.89815325 0.58787879]
#  [0.89356188 0.59393939]
#  [0.88888889 0.6       ]
#  [0.88413427 0.60606061]
#  [0.87929803 0.61212121]
#  [0.87438017 0.61818182]
#  [0.86938068 0.62424242]
#  [0.86429956 0.63030303]
#  [0.85913682 0.63636364]
#  [0.85389246 0.64242424]
#  [0.84856647 0.64848485]
#  [0.84315886 0.65454545]
#  [0.83766963 0.66060606]
#  [0.83209877 0.66666667]
#  [0.82644628 0.67272727]
#  [0.82071217 0.67878788]
#  [0.81489644 0.68484848]
#  [0.80899908 0.69090909]
#  [0.8030201  0.6969697 ]
#  [0.79695949 0.7030303 ]
#  [0.79081726 0.70909091]
#  [0.78459341 0.71515152]
#  [0.77828793 0.72121212]
#  [0.77190083 0.72727273]
#  [0.7654321  0.73333333]
#  [0.75888175 0.73939394]
#  [0.75224977 0.74545455]
#  [0.74553617 0.75151515]
#  [0.73874094 0.75757576]
#  [0.7318641  0.76363636]
#  [0.72490562 0.76969697]
#  [0.71786552 0.77575758]
#  [0.7107438  0.78181818]
#  [0.70354046 0.78787879]
#  [0.69625548 0.79393939]
#  [0.68888889 0.8       ]
#  [0.68144067 0.80606061]
#  [0.67391083 0.81212121]
#  [0.66629936 0.81818182]
#  [0.65860626 0.82424242]
#  [0.65083155 0.83030303]
#  [0.64297521 0.83636364]
#  [0.63503724 0.84242424]
#  [0.62701765 0.84848485]
#  [0.61891644 0.85454545]
#  [0.6107336  0.86060606]
#  [0.60246914 0.86666667]
#  [0.59412305 0.87272727]
#  [0.58569534 0.87878788]
#  [0.577186   0.88484848]
#  [0.56859504 0.89090909]
#  [0.55992246 0.8969697 ]
#  [0.55116825 0.9030303 ]
#  [0.54233242 0.90909091]
#  [0.53341496 0.91515152]
#  [0.52441588 0.92121212]
#  [0.51533517 0.92727273]
#  [0.50617284 0.93333333]
#  [0.49692888 0.93939394]
#  [0.48760331 0.94545455]
#  [0.4781961  0.95151515]
#  [0.46870727 0.95757576]
#  [0.45913682 0.96363636]
#  [0.44948475 0.96969697]
#  [0.43975105 0.97575758]
#  [0.42993572 0.98181818]
#  [0.42003877 0.98787879]
#  [0.4100602  0.99393939]
#  [0.4        1.        ]]

# %%
strokeObj = StrokeType()
#all the demo strokes

strokeData = [[[0,1], [1.64989518, 1-0.33707865], [1, 0]]]
fig, ax, curvePoints = plotStroke(strokeData)
strokeObj.set("E0", "㇀", strokeData, strokeData)
saveStroke(strokeObj)

strokeData = [[[0,1], [0.64989518, 1-0.33707865], [1, 0]]]
fig, ax, curvePoints = plotStroke(strokeData)
strokeObj.set("C0", "㇀", strokeData, strokeData)
saveStroke(strokeObj)

strokeData = [[[0, 1], [1.09574468, 1-0.12790698], [1.01595745, 1-0.50581395],[1, 0]]]
fig, ax, curvePoints = plotStroke(strokeData)
strokeObj.set("C1", "㇁", strokeData, strokeData)
saveStroke(strokeObj)

strokeData = [[ [0,1-1],[ 0.02970297, 1-0.08925319],[-0.03920792,1-0.03096539],[-0.01980198,1+0.01371585],
       [0.0990099,1+0.01025137],[1,1] ]]
fig, ax, curvePoints = plotStroke(strokeData)
strokeObj.set("C4", "㇄", strokeData, strokeData)
saveStroke(strokeObj)

strokeData = [[[0,.5], [1, .5]]]
fig, ax, curvePoints = plotStroke(strokeData)
strokeObj.set("D0", "㇐", strokeData, strokeData)
saveStroke(strokeObj)

strokeData = [[[.5,0], [.5, 1]]]
fig, ax, curvePoints = plotStroke(strokeData)
strokeObj.set("D1", "㇑", strokeData, strokeData)
saveStroke(strokeObj)


strokeData = [[[0.1,1-1],[0.7,1-1]],[[0.7,1-1],[0.5,1-0.6]],[[0.5,1-0.6],[1,1-0.6]],[[1,1-0.6],[0.9,1-0.3],[0.4,1-0]]]
#fig, ax, curvePoints = plotStroke(strokeData)
#strokeObj = StrokeType()
#strokeObj.set("HZZP", "㇋", strokeData, strokeData)
#saveStroke(strokeObj)

# %%
strokeData = [[[0.1,1-1],[0.7,1-1]],[[0.7,1-1],[0.5,1-0.6]],[[0.5,1-0.6],[1,1-0.6]],[[1,1-0.6],[0.9,1-0.3],[0.4,1-0]]]
print(np.array(strokeData))
fig, ax, curvePoints = plotStroke(strokeData)
strokeObj = StrokeType()
strokeObj.set("HZZP", "㇋", strokeData, strokeData)
saveStroke(strokeObj)
# Out:
# [[[0.1 0. ]
#   [0.7 0. ]
#   [0.7 0. ]]
#
#  [[0.7 0. ]
#   [0.5 0.4]
#   [0.5 0.4]]
#
#  [[0.5 0.4]
#   [1.  0.4]
#   [1.  0.4]]
#
#  [[1.  0.4]
#   [0.9 0.7]
#   [0.4 1. ]]]

# %%
print(len(strokeData))

filter(lambda x: x % 2 == 0, tuple)

for seg in strokeData
# Out:
# 4

# %%
max(len(subList) for subList in strokeData)
# Out:
# 5

# %%
strokeData = [[[0.1,1-1],[0.7,1-1]],[[0.7,1-1],[0.5,1-0.6]],[[0.5,1-0.6],[1,1-0.6]],[[1,1-0.6],[0.9,1-0.3],[0.4,1-0]]]
