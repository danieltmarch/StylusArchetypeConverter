# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(16,16))

font = {'family': 'serif',
        'font': 'Arial',
        'color':  'black',
        'weight': 'normal',
        'size': 400,
        }
ax.text(.35,.4,'t我', fontdict=font)
# Out:
# Text(0.35, 0.4, 't我')
# C:\Users\Lemon\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 25105 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Lemon\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 25105 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as mfm

#ya hei font, "exactly" the same as Arial Unicode
prop = mfm.FontProperties(fname='../Fonts/msyh.ttc')

fig, ax = plt.subplots(figsize=(16,16))
ax.text(.08,.2, s='\u4f4d', fontproperties=prop, fontsize=750)

matr = ax
np.shape(matr)
# Out:
# ()

# %%
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
import matplotlib.pyplot as plt

#Heavily based on https://stackoverflow.com/a/27753869/190597 (jsheperd)
def renderFormalImage(char, path='../Fonts/msyh.ttc', fontsize=800, show=False):
    font = ImageFont.truetype(path, fontsize) 
    w, h = font.getsize(char)
    h *= 2
    image = Image.new('L', (w, h), 1)  
    draw = ImageDraw.Draw(image)
    draw.text((0, 0), char, font=font)
    arr = np.asarray(image)
    arr = np.where(arr, 0, 1)
    arr = arr[(arr != 0).any(axis=1)]
    
    if(show):
        plt.imshow(arr)    
    return arr

renderFormalImage("\u4f4d", show=True);

print(np.shape(renderFormalImage("\u4f4d")))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f4d88501855e> in <module>
#      18     return arr
#      19
# ---> 20 renderFormalImage("\u4f4d", show=True);
#      21
#      22 print(np.shape(renderFormalImage("\u4f4d")))
#
# <ipython-input-4-f4d88501855e> in renderFormalImage(char, path, fontsize, show)
#       4 #Heavily based on https://stackoverflow.com/a/27753869/190597 (jsheperd)
#       5 def renderFormalImage(char, path='../Fonts/msyh.ttc', fontsize=800, show=False):
# ----> 6     font = PIL.ImageFont.truetype(path, fontsize)
#       7     w, h = font.getsize(char)
#       8     h *= 2
#
# AttributeError: module 'PIL' has no attribute 'ImageFont'

# %%
import FormalImage as fi

charImg = fi.renderChar('\u4f4d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b251a24c4d81> in <module>
#       1 import FormalImage as fi
#       2
# ----> 3 charImg = fi.renderFormalImage('\u4f4d')
#
# F:\Users\Daniel\OneDrive\School\Notes\Biola 2022 Fall Semester\Other\Hanzi App\Code\FormalImage.py in renderFormalImage(char, path, fontsize, show)
#      16     draw = ImageDraw.Draw(image)
#      17     draw.text((0, 0), char, font=font)
# ---> 18     arr = np.asarray(image)
#      19     arr = np.where(arr, 0, 1)
#      20     arr = arr[(arr != 0).any(axis=1)]
#
# NameError: name 'np' is not defined
